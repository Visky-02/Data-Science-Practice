# %%
# this is a comment
print('Hello')
# Out:
# Hello

# %%
# integer type
x=10

# %%
type(x)
# Out:
# int

# %%
x
# Out:
# 10

# %%
#float
y=7.5

# %%
type(y)
# Out:
# float

# %%
y
# Out:
# 7.5

# %%
#boolean
z = True

# %%
type(z)
# Out:
# bool

# %%
z
# Out:
# True
