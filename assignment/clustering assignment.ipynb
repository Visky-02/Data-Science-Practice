# %%
import os

print("1. Python abhi is folder mein khada hai:")
print(os.getcwd())

print("\n2. Python ko apne aas-paas ye files aur folders dikh rahe hain:")
print(os.listdir())
# Out:
# 1. Python abhi is folder mein khada hai:
# C:\Users\Vishal Parmar\python practice
#
# 2. Python ko apne aas-paas ye files aur folders dikh rahe hain:
# ...
