# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm, t, binom

data6 = {
    'Student_ID': range(1, 16),
    'Course': ['Typing', 'Steno', 'Typing', 'Typing', 'Steno', 'Steno', 'Typing', 'Steno', 'Typing', 'Typing', 'Steno', 'Typing', 'Steno', 'Steno', 'Typing'],
    'Mock_Score': [65, 82, 45, 91, 78, np.nan, 55, 88, 72, 39, 85, 95, 76, np.nan, 60]
}
df6 = pd.DataFrame(data6)

# %%
df6
# Out:
#     Student_ID  Course  Mock_Score
# 0            1  Typing        65.0
# 1            2   Steno        82.0
# 2            3  Typing        45.0
# 3            4  Typing        91.0
# 4            5   Steno        78.0
# 5            6   Steno         NaN
# 6            7  Typing        55.0
# 7            8   Steno        88.0
# 8            9  Typing        72.0
# 9           10  Typing        39.0
# 10          11   Steno        85.0
# 11          12  Typing        95.0
# 12          13   Steno        76.0
# 13          14   Steno         NaN
# 14          15  Typing        60.0

# %%
a12=df6['Mock_Score']('Steno').mean()
a12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a12=df6['Mock_Score']('Steno').mean()
#       2 a12
#
# TypeError: 'Series' object is not callable

# %%
df6.groupby('Course')['Mock_Score'].mean()
# Out:
# Course
# Steno     81.80
# Typing    65.25
# Name: Mock_Score, dtype: float64

# %%
df6.fillna({'Mock_Score':a12[1]},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df6.fillna({'Mock_Score':a12[1]},inplace=True)
#
# IndexError: invalid index to scalar variable.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm, t, binom
import scipy.stats as stats
from pandasql import sqldf

# %%
def calculate_z(x_bar, mu, sigma, n):
    z=(x_bar-mu)/(sigma/np.sqrt(n))
    return z

# %%
calculate_z(2990,3262,1100,50):
# Out:
#   Cell In[12], line 1
#     calculate_z(2990,3262,1100,50):
#                                   ^
# SyntaxError: invalid syntax
