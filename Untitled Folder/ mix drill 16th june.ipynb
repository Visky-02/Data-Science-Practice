# %%
import pandas as pd

# Run this to setup your DA/BA scenario
data = {
    'Transaction_ID': ['TX101', 'TX102', 'TX103', 'TX102', 'TX104', 'TX101'],
    'Order_Date': ['15-06-2026', '16-06-2026', '16-06-2026', '16-06-2026', '17-06-2026', '15-06-2026'],
    'Payment_Status': ['Pending', 'Failed', 'Success', 'Success', 'Success', 'Success']
}

sales_df = pd.DataFrame(data)
print("Before Cleaning:\n", sales_df)
# Out:
# Before Cleaning:
#    Transaction_ID  Order_Date Payment_Status
# 0          TX101  15-06-2026        Pending
# 1          TX102  16-06-2026         Failed
# 2          TX103  16-06-2026        Success
# 3          TX102  16-06-2026        Success
# 4          TX104  17-06-2026        Success
# 5          TX101  15-06-2026        Success

# %%
sales_df.head()
# Out:
#   Transaction_ID  Order_Date Payment_Status
# 0          TX101  15-06-2026        Pending
# 1          TX102  16-06-2026         Failed
# 2          TX103  16-06-2026        Success
# 3          TX102  16-06-2026        Success
# 4          TX104  17-06-2026        Success

# %%
sales_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  6 non-null      str
#  1   Order_Date      6 non-null      str
#  2   Payment_Status  6 non-null      str
# dtypes: str(3)
# memory usage: 276.0 bytes

# %%
import pandas as pd
sales_df['Order_Date']=pd.to_datetime(sales_df['Order_Date'],format='%d-%m-%Y')

# %%
sales_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  6 non-null      str
#  1   Order_Date      6 non-null      datetime64[us]
#  2   Payment_Status  6 non-null      str
# dtypes: datetime64[us](1), str(2)
# memory usage: 276.0 bytes

# %%
sales_df=sales_df.drop_duplicates(subset=['Transaction_ID'],keep='last')

# %%
sales_df
# Out:
#   Transaction_ID Order_Date Payment_Status
# 2          TX103 2026-06-16        Success
# 3          TX102 2026-06-16        Success
# 4          TX104 2026-06-17        Success
# 5          TX101 2026-06-15        Success

# %%
# Run this to setup Q2 data
data_q2 = {
    'Region': ['North', 'North', 'South', 'South', 'East', 'North', 'East'],
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Furniture', 'Clothing', 'Electronics', 'Electronics'],
    'Sales': [5000, 2000, 7000, 3000, 1500, 4000, 6000]
}

sales_region_df = pd.DataFrame(data_q2)
print("Raw Sales Data:\n", sales_region_df)
# Out:
# Raw Sales Data:
#    Region     Category  Sales
# 0  North  Electronics   5000
# 1  North     Clothing   2000
# 2  South  Electronics   7000
# 3  South    Furniture   3000
# 4   East     Clothing   1500
# 5  North  Electronics   4000
# 6   East  Electronics   6000

# %%
sales_region_df
# Out:
#   Region     Category  Sales
# 0  North  Electronics   5000
# 1  North     Clothing   2000
# 2  South  Electronics   7000
# 3  South    Furniture   3000
# 4   East     Clothing   1500
# 5  North  Electronics   4000
# 6   East  Electronics   6000

# %%
pd.pivot_table(data=sales_region_df,values='Sales',index='Region',columns='Category',aggfunc='sum',fill_value=0)
# Out:
# Category  Clothing  Electronics  Furniture
# Region
# East          1500         6000          0
# North         2000         9000          0
# South            0         7000       3000

# %%
sales_region_df=sales_region_df.fillna(0)

# %%
pd.pivot_table(data=sales_region_df,values='Sales',index='Region',columns='Category',aggfunc='sum')
# Out:
# Category  Clothing  Electronics  Furniture
# Region
# East        1500.0       6000.0        NaN
# North       2000.0       9000.0        NaN
# South          NaN       7000.0     3000.0

# %%
import pandas as pd
import numpy as np

# Run this to setup Q3 data
data_q3 = {
    'Customer_ID': ['C1', 'C2', 'C3', 'C4', 'C5'],
    'Total_Spend': [15000, 4500, 25000, 8000, 12000],
    'Return_Rate': [0.05, 0.35, 0.02, 0.12, 0.25]  # 0.05 matlab 5% return rate
}

customer_df = pd.DataFrame(data_q3)
print("Raw Customer Data:\n", customer_df)
# Out:
# Raw Customer Data:
#    Customer_ID  Total_Spend  Return_Rate
# 0          C1        15000         0.05
# 1          C2         4500         0.35
# 2          C3        25000         0.02
# 3          C4         8000         0.12
# 4          C5        12000         0.25

# %%
customer_df
# Out:
#   Customer_ID  Total_Spend  Return_Rate
# 0          C1        15000         0.05
# 1          C2         4500         0.35
# 2          C3        25000         0.02
# 3          C4         8000         0.12
# 4          C5        12000         0.25

# %%
customer_df['Customer_Segment']=customer_df.apply(lambda x: "VIP" if 
                                                  customer_df[(customer_df['Total_Spend']>10000) & (customer_df['Return_Rate']<0.10)] 
                                                  else "Normal")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12512\2980398299.py in ?()
# ----> 1 customer_df['Customer_Segment']=customer_df.apply(lambda x: "VIP" if
#       2                                                   customer_df[(customer_df['Total_Spend']>10000) & (customer_df['Return_Rate']<0.10)]
#       3                                                   else "Normal")
#
# ~\anaconda34\Lib\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12431                 engine_kwargs=engine_kwargs,
#   12432                 args=args,
#   12433                 kwargs=kwargs,
#   12434             )
# > 12435             return op.apply().__finalize__(self, method="apply")
#   12436         elif hasattr(engine, "__pandas_udf__"):
#   12437             if result_type is not None:
# ...

# %%
if customer_df['Total_Spend']>10000:
    print("VIP")
    else
        print("Standard")
# Out:
#   Cell In[29], line 3
#     else
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
cond1=(customer_df['Total_Spend']>10000)&(customer_df['Return_Rate']<0.10)
cond2=(customer_df['Total_Spend']>10000)&(customer_df['Return_Rate']>=0.10)
customer_df['Customer_Segment']=np.select([cond1,cond2],['VIP','High_Spend-At Risk'],default='Standard')
print(customer_df)
# Out:
#   Customer_ID  Total_Spend  Return_Rate    Customer_Segment
# 0          C1        15000         0.05                 VIP
# 1          C2         4500         0.35            Standard
# 2          C3        25000         0.02                 VIP
# 3          C4         8000         0.12            Standard
# 4          C5        12000         0.25  High_Spend-At Risk

# %%
# Lambda ke andar Nested If-Else lagta hai
customer_df['Segment_Lambda'] = customer_df.apply(
    lambda row: 'VIP' if (row['Total_Spend'] > 10000 and row['Return_Rate'] < 0.10) 
                else ('High Spend - At Risk' if (row['Total_Spend'] > 10000 and row['Return_Rate'] >= 0.10) 
                else 'Standard'), 
    axis=1 # IMPORTANT: Ye Python ko bolta hai "Bhai, Row by Row check kar!"
)

print(customer_df)
# Out:
#   Customer_ID  Total_Spend  Return_Rate    Customer_Segment  \
# 0          C1        15000         0.05                 VIP
# 1          C2         4500         0.35            Standard
# 2          C3        25000         0.02                 VIP
# 3          C4         8000         0.12            Standard
# 4          C5        12000         0.25  High_Spend-At Risk
#
#          Segment_Lambda
# 0                   VIP
# 1              Standard
# 2                   VIP
# 3              Standard
# 4  High Spend - At Risk

# %%
# Run this to setup Q4 data
raw_codes = ['  eLec-101 ', 'cloTH-202', '  fUrN-303  ', 'eleC-104']

print("Kachra Data:", raw_codes)
# Out:
# Kachra Data: ['  eLec-101 ', 'cloTH-202', '  fUrN-303  ', 'eleC-104']

# %%
raw_codes
# Out:
# ['  eLec-101 ', 'cloTH-202', '  fUrN-303  ', 'eleC-104']

# %%
raw_codes.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 raw_codes.strip()
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
raw_codes.str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 raw_codes.str.upper()
#
# AttributeError: 'list' object has no attribute 'str'

# %%
clean_codes = [x.strip().upper() for x in raw_codes]
print(clean_codes)
# Out:
# ['ELEC-101', 'CLOTH-202', 'FURN-303', 'ELEC-104']

# %%
import pandas as pd

# Run this to setup Q5 data
data_q5 = {
    'Region': ['North', 'East', 'South', 'North', 'West', 'South'],
    'Sales': [6000, 7000, 4500, 3000, 8000, 9000]
}
df_q5 = pd.DataFrame(data_q5)
print("Raw Data:\n", df_q5)
# Out:
# Raw Data:
#    Region  Sales
# 0  North   6000
# 1   East   7000
# 2  South   4500
# 3  North   3000
# 4   West   8000
# 5  South   9000

# %%
df_q5
# Out:
#   Region  Sales
# 0  North   6000
# 1   East   7000
# 2  South   4500
# 3  North   3000
# 4   West   8000
# 5  South   9000

# %%
# Dono conditions ko round brackets () mein rakhna zaroori hai
final_report = df_q5[ (df_q5['Region'].isin(['North', 'South'])) & (df_q5['Sales'] > 5000) ]

print(final_report)
# Out:
#   Region  Sales
# 0  North   6000
# 5  South   9000

# %%
import pandas as pd

# Run this to setup Q6 data
data_q6 = {
    'Region': ['North', 'South', 'North', 'East', 'South', 'East'],
    'Sales': [5000, 7000, 3000, 4000, 9000, 6000],
    'Discount': [0.10, 0.15, 0.05, 0.20, 0.10, 0.25]
}

df_q6 = pd.DataFrame(data_q6)
print("Raw Business Data:\n", df_q6)
# Out:
# Raw Business Data:
#    Region  Sales  Discount
# 0  North   5000      0.10
# 1  South   7000      0.15
# 2  North   3000      0.05
# 3   East   4000      0.20
# 4  South   9000      0.10
# 5   East   6000      0.25

# %%
df_q6.groupby('Region')[['Sales','Discount']].agg({'sum','mean'})
# Out:
#         Sales         Discount
#           sum    mean      sum   mean
# Region
# East    10000  5000.0     0.45  0.225
# North    8000  4000.0     0.15  0.075
# South   16000  8000.0     0.25  0.125

# %%
# Yahan dictionary specify kar rahi hai ki kis column ke sath kya karna hai
perfect_summary = df_q6.groupby('Region').agg({
    'Sales': 'sum', 
    'Discount': 'mean'
})

print(perfect_summary)
# Out:
#         Sales  Discount
# Region
# East    10000     0.225
# North    8000     0.075
# South   16000     0.125

# %%
import numpy as np

# Run this to setup Q7 data
data_q7 = {
    'Emp_ID': ['E01', 'E02', 'E03', 'E04', 'E05'],
    'Age': [25, np.nan, 28, 32, np.nan],
    'Bonus': [np.nan, 5000, 6000, np.nan, 7000]
}

hr_df = pd.DataFrame(data_q7)
print("Raw HR Data:\n", hr_df)
# Out:
# Raw HR Data:
#    Emp_ID   Age   Bonus
# 0    E01  25.0     NaN
# 1    E02   NaN  5000.0
# 2    E03  28.0  6000.0
# 3    E04  32.0     NaN
# 4    E05   NaN  7000.0

# %%
mean_age=hr_df['Age'].mean()

# %%
hr_df['Age']=hr_df['Age'].fillna(mean_age)

# %%
hr_df
# Out:
#   Emp_ID        Age   Bonus
# 0    E01  25.000000     NaN
# 1    E02  28.333333  5000.0
# 2    E03  28.000000  6000.0
# 3    E04  32.000000     NaN
# 4    E05  28.333333  7000.0

# %%
hr_df['Bonus']=hr_df['Bonus'].fillna(0)

# %%
hr_df
# Out:
#   Emp_ID        Age   Bonus
# 0    E01  25.000000     0.0
# 1    E02  28.333333  5000.0
# 2    E03  28.000000  6000.0
# 3    E04  32.000000     0.0
# 4    E05  28.333333  7000.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Run this to setup Q8 data
data_q8 = {
    'Department': ['IT', 'IT', 'IT', 'IT', 'HR', 'HR', 'HR', 'Sales', 'Sales', 'Sales', 'Sales'],
    'Salary': [60000, 65000, 62000, 150000, 40000, 42000, 41000, 50000, 55000, 52000, 120000] 
    # Notice 150k in IT and 120k in Sales are outliers
}

salary_df = pd.DataFrame(data_q8)
print("Salary Data Loaded!")
# Out:
# Salary Data Loaded!

# %%
salary_df
# Out:
#    Department  Salary
# 0          IT   60000
# 1          IT   65000
# 2          IT   62000
# 3          IT  150000
# 4          HR   40000
# 5          HR   42000
# 6          HR   41000
# 7       Sales   50000
# 8       Sales   55000
# 9       Sales   52000
# 10      Sales  120000

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x='Salary',y='Department',data=salary_df)
plt.show()

# %%
q1=salary_df['Salary'].quantile(0.25)
q3=salary_df['Salary'].quantile(0.75)
IQR=q3-q1

# %%
lower_bound=q1-(1.5*IQR)
upper_bound=q3+(1.5*IQR)

# %%
lower_bound
# Out:
# 19750.0

# %%
upper_bound
# Out:
# 89750.0

# %%
outlier_salary_df=salary_df[salary_df['Salary']>upper_bound]

# %%
outlier_salary_df
# Out:
#    Department  Salary
# 3          IT  150000
# 10      Sales  120000

# %%
import pandas as pd

# Run this to setup Q11 data (Notice: Date is already pd.to_datetime)
data_q11 = {
    'Order_Date': pd.to_datetime(['2026-01-15', '2026-01-20', '2026-02-10', '2026-02-25', '2026-03-05']),
    'Sales': [5000, 3000, 7000, 4000, 10000]
}

sales_df = pd.DataFrame(data_q11)
print("Data Ready:\n", sales_df)
# Out:
# Data Ready:
#    Order_Date  Sales
# 0 2026-01-15   5000
# 1 2026-01-20   3000
# 2 2026-02-10   7000
# 3 2026-02-25   4000
# 4 2026-03-05  10000

# %%
sales_df['Month'] = sales_df['Order_Date'].dt.month

# %%
sales_df
# Out:
#   Order_Date  Sales  Month
# 0 2026-01-15   5000      1
# 1 2026-01-20   3000      1
# 2 2026-02-10   7000      2
# 3 2026-02-25   4000      2
# 4 2026-03-05  10000      3

# %%
monthly_summary = sales_df.groupby('Month')['Sales'].sum().reset_index()

# %%
monthly_summary
# Out:
#    Month  Sales
# 0      1   8000
# 1      2  11000
# 2      3  10000

# %%
a=monthly_summary['Sales'].sum()

# %%
monthly_summary['Sales_Percentage']=((monthly_summary['Sales']/a)*100).round(2)

# %%
monthly_summary
# Out:
#    Month  Sales  Sales_Percentage
# 0      1   8000             27.59
# 1      2  11000             37.93
# 2      3  10000             34.48

# %%
import pandas as pd

# Run this to setup Q1 data
data_q1 = {
    'Student_ID': ['S101', 'S102', 'S103', 'S104', 'S105'],
    'Course_Name': ['  Tally Prime', 'dca ', '  PGDCA ', 'tally prime', '  MS Office']
}

enrollment_df = pd.DataFrame(data_q1)
print("Raw Enrollment Data:\n", enrollment_df)
# Out:
# Raw Enrollment Data:
#    Student_ID    Course_Name
# 0       S101    Tally Prime
# 1       S102           dca
# 2       S103         PGDCA
# 3       S104    tally prime
# 4       S105      MS Office

# %%
enrollment_df['Course_Name']=enrollment_df['Course_Name'].str.strip().str.upper()

# %%
enrollment_df
# Out:
#   Student_ID  Course_Name
# 0       S101  TALLY PRIME
# 1       S102          DCA
# 2       S103        PGDCA
# 3       S104  TALLY PRIME
# 4       S105    MS OFFICE

# %%
import pandas as pd

# Run this to setup Q2 data
data_q2 = {
    'Student_Name': ['Amit', 'Rahul', 'Neha', 'Pooja', 'Sonia'],
    'Marks': [75, 88, 92, 60, 81]
}

marks_df = pd.DataFrame(data_q2)
print("Raw Marks Data:\n", marks_df)
# Out:
# Raw Marks Data:
#    Student_Name  Marks
# 0         Amit     75
# 1        Rahul     88
# 2         Neha     92
# 3        Pooja     60
# 4        Sonia     81

# %%
marks_df[marks_df['Marks']>80]
# Out:
#   Student_Name  Marks
# 1        Rahul     88
# 2         Neha     92
# 4        Sonia     81

# %%
marks_df['Marks'].sort_values(ascending=False)
# Out:
# 2    92
# 1    88
# 4    81
# 0    75
# 3    60
# Name: Marks, dtype: int64

# %%
marks_df = marks_df.sort_values(by='Marks', ascending=False)

# %%
marks_df
# Out:
#   Student_Name  Marks
# 2         Neha     92
# 1        Rahul     88
# 4        Sonia     81
# 0         Amit     75
# 3        Pooja     60

# %%
import pandas as pd
import numpy as np

# Run this to setup data for Q16 to Q20
data_batch = {
    'Emp_ID': [1, 2, 3, 4, 5],
    'Name': ['Ravi', 'Priya', 'Kiran', 'Amit', 'Neha'],
    'Dept': ['IT', 'HR', 'IT', 'Sales', 'HR'],
    'Salary': [50000, 60000, np.nan, 45000, 55000],
    'Rating': ['A', 'B', 'A', 'C', 'B']
}
df_batch = pd.DataFrame(data_batch)
print("Batch Data Loaded Successfully!")
# Out:
# Batch Data Loaded Successfully!

# %%
df_batch
# Out:
#    Emp_ID   Name   Dept   Salary Rating
# 0       1   Ravi     IT  50000.0      A
# 1       2  Priya     HR  60000.0      B
# 2       3  Kiran     IT      NaN      A
# 3       4   Amit  Sales  45000.0      C
# 4       5   Neha     HR  55000.0      B

# %%
df_batch['Rating']=df_batch['Rating'].replace({'A':'Excellent','B':'Good','C':'Average'})

# %%
df_batch
# Out:
#    Emp_ID   Name   Dept   Salary     Rating
# 0       1   Ravi     IT  50000.0  Excellent
# 1       2  Priya     HR  60000.0       Good
# 2       3  Kiran     IT      NaN  Excellent
# 3       4   Amit  Sales  45000.0    Average
# 4       5   Neha     HR  55000.0       Good

# %%
df_batch.dropna(inplace=True)

# %%
df_batch
# Out:
#    Emp_ID   Name   Dept   Salary     Rating
# 0       1   Ravi     IT  50000.0  Excellent
# 1       2  Priya     HR  60000.0       Good
# 3       4   Amit  Sales  45000.0    Average
# 4       5   Neha     HR  55000.0       Good

# %%
df_batch['Dept'].value_counts()
# Out:
# Dept
# HR       2
# IT       1
# Sales    1
# Name: count, dtype: int64

# %%
df_batch['Bonus']=df_batch['Salary']*0.10

# %%
df_batch
# Out:
#    Emp_ID   Name   Dept   Salary     Rating   Bonus
# 0       1   Ravi     IT  50000.0  Excellent  5000.0
# 1       2  Priya     HR  60000.0       Good  6000.0
# 3       4   Amit  Sales  45000.0    Average  4500.0
# 4       5   Neha     HR  55000.0       Good  5500.0

# %%
df_batch[['Name','Bonus']]
# Out:
#     Name   Bonus
# 0   Ravi  5000.0
# 1  Priya  6000.0
# 3   Amit  4500.0
# 4   Neha  5500.0

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Run this to setup data for Q21 to Q25 (E-commerce Data)
data_final = {
    'Order_ID': ['ORD-1', 'ORD-2', 'ORD-3', 'ORD-4', 'ORD-5', 'ORD-6'],
    'Customer_Name': ['amit', ' rahul', 'NEHA', 'pooja ', '  KIRAN', 'amit'],
    'Order_Date': ['2026-03-01', '2026-03-15', '2026-04-05', '2026-04-20', '2026-05-10', '2026-03-01'],
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Electronics'],
    'Spend': [12000, 3000, 15000, 4500, 80000, 12000] # Notice outlier in Kiran's spend and duplicate Amit
}
df_final = pd.DataFrame(data_final)
print("Final Batch Data Loaded!")
# Out:
# Final Batch Data Loaded!

# %%
df_final
# Out:
#   Order_ID Customer_Name  Order_Date     Category  Spend
# 0    ORD-1          amit  2026-03-01  Electronics  12000
# 1    ORD-2         rahul  2026-03-15     Clothing   3000
# 2    ORD-3          NEHA  2026-04-05  Electronics  15000
# 3    ORD-4        pooja   2026-04-20     Clothing   4500
# 4    ORD-5         KIRAN  2026-05-10  Electronics  80000
# 5    ORD-6          amit  2026-03-01  Electronics  12000

# %%
df_final.drop_duplicates(subset=['Customer_Name', 'Order_Date', 'Category', 'Spend'], keep='first')
# Out:
#   Order_ID Customer_Name  Order_Date     Category  Spend
# 0    ORD-1          amit  2026-03-01  Electronics  12000
# 1    ORD-2         rahul  2026-03-15     Clothing   3000
# 2    ORD-3          NEHA  2026-04-05  Electronics  15000
# 3    ORD-4        pooja   2026-04-20     Clothing   4500
# 4    ORD-5         KIRAN  2026-05-10  Electronics  80000

# %%
df_final['Customer_Name']=df_final['Customer_Name'].str.strip().str.title()

# %%
df_final
# Out:
#   Order_ID Customer_Name  Order_Date     Category  Spend
# 0    ORD-1          Amit  2026-03-01  Electronics  12000
# 1    ORD-2         Rahul  2026-03-15     Clothing   3000
# 2    ORD-3          Neha  2026-04-05  Electronics  15000
# 3    ORD-4         Pooja  2026-04-20     Clothing   4500
# 4    ORD-5         Kiran  2026-05-10  Electronics  80000
# 5    ORD-6          Amit  2026-03-01  Electronics  12000

# %%
df_final=df_final.drop_duplicates(subset='Customer_Name',keep='first')

# %%
df_final
# Out:
#   Order_ID Customer_Name  Order_Date     Category  Spend
# 0    ORD-1          Amit  2026-03-01  Electronics  12000
# 1    ORD-2         Rahul  2026-03-15     Clothing   3000
# 2    ORD-3          Neha  2026-04-05  Electronics  15000
# 3    ORD-4         Pooja  2026-04-20     Clothing   4500
# 4    ORD-5         Kiran  2026-05-10  Electronics  80000

# %%
import pandas as pd
df_final['Order_Date']=pd.to_datetime(df_final['Order_Date'],format='%d-%m-%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[135], line 2
#       1 import pandas as pd
# ----> 2 df_final['Order_Date']=pd.to_datetime(df_final['Order_Date'],format='%d-%m-%Y')
#
# File ~\anaconda34\Lib\site-packages\pandas\core\tools\datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1042 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda34\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,6))
sns.barplot(x='Category',y='Spend',data=df_final,estimator=np.sum)
plt.xlabel("CATEGORY")
plt.ylabel("TOTAL SPEND")
plt.title("Spending on Each Category")
plt.show()

# %%
df_final
# Out:
#   Order_ID Customer_Name  Order_Date     Category  Spend
# 0    ORD-1          Amit  2026-03-01  Electronics  12000
# 1    ORD-2         Rahul  2026-03-15     Clothing   3000
# 2    ORD-3          Neha  2026-04-05  Electronics  15000
# 3    ORD-4         Pooja  2026-04-20     Clothing   4500
# 4    ORD-5         Kiran  2026-05-10  Electronics  80000

# %%
mean=df_final['Spend'].mean()

# %%
mean
# Out:
# 22900.0

# %%
std=df_final['Spend'].std()

# %%
std
# Out:
# 32311.76256411897

# %%
df_final['Is_Outlier']=df_final['Spend'].apply(lambda x:'YES' if x>(mean + 2 * std) else 'NO')

# %%
df_final
# Out:
#   Order_ID Customer_Name  Order_Date     Category  Spend Is_Outlier
# 0    ORD-1          Amit  2026-03-01  Electronics  12000         NO
# 1    ORD-2         Rahul  2026-03-15     Clothing   3000         NO
# 2    ORD-3          Neha  2026-04-05  Electronics  15000         NO
# 3    ORD-4         Pooja  2026-04-20     Clothing   4500         NO
# 4    ORD-5         Kiran  2026-05-10  Electronics  80000         NO

# %%
# Pehle Date fix ki
df_final['Order_Date'] = pd.to_datetime(df_final['Order_Date'])

# Phir multi-condition filter lagaya
april_electronics = df_final[(df_final['Order_Date'].dt.month == 4) & (df_final['Category'] == 'Electronics')]
print(april_electronics)
# Out:
#   Order_ID Customer_Name Order_Date     Category  Spend
# 2    ORD-3          NEHA 2026-04-05  Electronics  15000
