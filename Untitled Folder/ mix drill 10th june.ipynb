# %%
import pandas as pd
movies=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.str.upper(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6172\28428258.py in ?()
# ----> 1 movies.str.upper(inplace=True)
#
# ~\anaconda34\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
movies.rename({'star_rating':'Rating','content_rating':'Age_group'},inplace=True)

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.loc[(movies['duration']>150)&(movies['genre']=='Action'),['title','star_rating']]
# Out:
#                                title  star_rating
# 3                    The Dark Knight          9.0
# 36               Saving Private Ryan          8.6
# 43             The Dark Knight Rises          8.5
# 44                         Gladiator          8.5
# 82                        Braveheart          8.4
# 129                              Ran          8.3
# 135                             Heat          8.3
# 385                        Spartacus          8.0
# 433                           Avatar          7.9
# 534                  The Longest Day          7.8
# 613                 The Last Samurai          7.7
# 649                Where Eagles Dare          7.7
# 671                       Grindhouse          7.7
# 684                     The Big Blue          7.7
# 707                         Watchmen          7.6
# 767  It's a Mad, Mad, Mad, Mad World          7.6
