# %%
import pandas as pd
daimond=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv")

# %%
daimond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
daimond.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  str
#  2   color    53940 non-null  str
#  3   clarity  53940 non-null  str
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), str(3)
# memory usage: 4.1 MB

# %%
columns_name=[col for col in daimond.columns]

# %%
columns_name
# Out:
# ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
expensive_daimond=daimond[(daimond['cut']=='Ideal')&(daimond['price']>5000)]

# %%
expensive_daimond.head()
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 11416   1.16  Ideal     E     SI2   62.7   56.0   5001  6.69  6.73  4.21
# 11417   1.16  Ideal     E     SI2   59.9   57.0   5001  6.80  6.82  4.08
# 11421   1.07  Ideal     I     SI1   61.7   56.1   5002  6.57  6.59  4.06
# 11422   1.10  Ideal     H     SI2   62.0   56.5   5002  6.58  6.63  4.09
# 11423   1.20  Ideal     J     SI1   62.1   55.0   5002  6.81  6.84  4.24

# %%
import numpy as np
np.mean(daimond['price'])
# Out:
# 3932.799721913237

# %%
daimond['carat'].agg({'mean','median'})
# Out:
# median    0.70000
# mean      0.79794
# Name: carat, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,6))
sns.boxplot(x='cut',y='price',data=daimond)
plt.xlabel("Daimond Cut ")
plt.ylabel("PRICE of Daimond")
plt.title("Price of daimond according to its cut")
plt.show()

# %%
aa=daimond.duplicated().sum()

# %%
aa
# Out:
# 146

# %%
daimond.drop_duplicates(inplace=True)

# %%
daimond.shape
# Out:
# (53794, 10)

# %%
a=daimond[daimond['cut']=='Premium']['cut'].count()

# %%
a
# Out:
# 13748

# %%
 daimond.shape
# Out:
# (53794, 10)

# %%
premium_cut_percent=a/53940*100

# %%
premium_cut_percent
# Out:
# 25.487578791249536

# %%
daimond.groupby(['cut','color'])['price'].max()
# Out:
# cut        color
# Fair       D        16386
#            E        15584
#            F        17995
#            G        18574
#            H        18565
#            I        18242
#            J        18531
# Good       D        18468
#            E        18236
#            F        18686
#            G        18788
#            H        18640
#            I        18707
#            J        18325
# Ideal      D        18693
#            E        18729
#            F        18780
#            G        18806
#            H        18760
#            I        18779
#            J        18508
# Premium    D        18575
#            E        18477
#            F        18791
#            G        18741
#            H        18795
#            I        18823
#            J        18710
# Very Good  D        18542
#            E        18731
#            F        18777
#            G        18818
#            H        18803
#            I        18500
#            J        18430
# ...

# %%
daimond[(daimond['cut']=='Ideal')&(daimond['color']=='D')].value_counts(ascending=False)
# Out:
# carat  cut    color  clarity  depth  table  price  x     y     z
# 0.30   Ideal  D      SI1      62.5   57.0   552    4.29  4.32  2.69    1
#                               62.1   56.0   552    4.30  4.33  2.68    1
# 0.71   Ideal  D      SI2      62.3   56.0   2762   5.73  5.69  3.56    1
#                      SI1      61.9   59.0   2764   5.69  5.72  3.53    1
#                      SI2      61.6   55.0   2767   5.74  5.76  3.54    1
#                                                                       ..
# 0.51   Ideal  D      VVS2     61.7   56.0   2742   5.16  5.14  3.18    1
#                               61.3   57.0   2742   5.17  5.14  3.16    1
# 0.81   Ideal  D      SI1      61.5   57.0   2748   6.00  6.03  3.70    1
# 0.72   Ideal  D      SI1      60.8   57.0   2757   5.75  5.76  3.50    1
# 0.75   Ideal  D      SI2      62.2   55.0   2757   5.83  5.87  3.64    1
# Name: count, Length: 2823, dtype: int64

# %%
from scipy import stats

price_ideal = daimond[daimond['cut'] == 'Ideal']['price']
price_premium = daimond[daimond['cut'] == 'Premium']['price']

t_stat, p_val = stats.ttest_ind(price_ideal, price_premium)
print(f"P-value is: {p_val}")
# Out:
# P-value is: 8.107205175961189e-142

# %%
from scipy import stats
price_ideal=daimond[daimond['cut']=='Ideal']['price']
price_premium=daimond[daimond['cut']=='Premium']['price']
t_stats,p_val=stats.ttest_ind(price_ideal,price_premium)
print(f"P-Value is : {p_val}")
# Out:
# P-Value is : 8.107205175961189e-142

# %%
col_with_e=[col for col in daimond.columns if 'e' in col]

# %%
col_with_e
# Out:
# ['depth', 'table', 'price']

# %%
daimond['price'].dtype
# Out:
# dtype('int64')

# %%
daimond['price']=daimond['price'].astype(float)

# %%
daimond['price'].dtype
# Out:
# dtype('float64')

# %%
daimond['Size_Category']=daimond['carat'].apply(lambda x: 'Big' if x>1.0 else "small")

# %%
daimond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  334.0  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75
#
#   Size_Category
# 0         small
# 1         small
# 2         small
# 3         small
# 4         small

# %%
daimond[['price','carat']].corr()
# Out:
#           price     carat
# price  1.000000  0.921548
# carat  0.921548  1.000000

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='carat',y='price',hue='cut',data=daimond)
plt.show()

# %%
daimond['Price_Per_Carat']=daimond['price']/daimond['carat']

# %%
daimond
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# ...

# %%
daimond['Price_Per_Carat'].max()
# Out:
# 17828.846153846152

# %%
pd.pivot_table(data=daimond, values='price', index='cut', columns='color', aggfunc='mean')
# Out:
# color                D            E            F            G            H  \
# cut
# Fair       4291.061350  3689.743243  3834.750809  4227.000000  5091.307692
# Good       3408.107576  3425.748657  3497.254405  4114.074799  4246.585122
# Ideal      2635.239107  2601.217056  3378.721131  3728.445838  3896.114369
# Premium    3634.493433  3542.385242  4327.297286  4498.782728  5217.907274
# Very Good  3472.662252  3215.471030  3777.724457  3874.210183  4524.835074
#
# color                I            J
# cut
# Fair       4607.534483  4975.655462
# Good       5032.471042  4587.833333
# Ideal      4452.125359  4922.871365
# Premium    5934.466245  6287.733251
# Very Good  5257.477140  5110.304284

# %%
ob_col=[col for col in daimond if daimond['col'].dtype==0 or daimond['col'].dtype='object']
# Out:
#   Cell In[134], line 1
#     ob_col=[col for col in daimond if daimond['col'].dtype==0 or daimond['col'].dtype='object']
#                                                                                      ^
# SyntaxError: invalid syntax

# %%
[col for col in daimond.columns if daimond[col].dtype == 'object']
# Out:
# []

# %%
daimond.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  str
#  2   color    53940 non-null  str
#  3   clarity  53940 non-null  str
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53934 non-null  float64
# dtypes: float64(4), str(3)
# memory usage: 2.9 MB

# %%
Q1=daimond['price'].quantile(0.25)

# %%
Q1
# Out:
# 951.0

# %%
Q3=daimond['price'].quantile(0.75)

# %%
Q3
# Out:
# 5326.75

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 4375.75

# %%
lower=Q1-(1.5*IQR)

# %%
lower
# Out:
# -5612.625

# %%
upper=Q3+(1.5*IQR)

# %%
upper
# Out:
# 11890.375

# %%
corr_data = daimond[['price', 'carat']].corr()

# %%
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
daimond.loc[0:5, 'price'] = np.nan

# %%
daimond.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      6
# x          0
# y          0
# z          0
# dtype: int64

# %%
daimond.query('cut == "Ideal" and color == "D"')
# Out:
#        carat    cut color clarity  depth  table   price     x     y     z
# 62      0.30  Ideal     D     SI1   62.5   57.0   552.0  4.29  4.32  2.69
# 63      0.30  Ideal     D     SI1   62.1   56.0   552.0  4.30  4.33  2.68
# 120     0.71  Ideal     D     SI2   62.3   56.0  2762.0  5.73  5.69  3.56
# 132     0.71  Ideal     D     SI1   61.9   59.0  2764.0  5.69  5.72  3.53
# 144     0.71  Ideal     D     SI2   61.6   55.0  2767.0  5.74  5.76  3.54
# ...      ...    ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53854   0.51  Ideal     D    VVS2   61.7   56.0  2742.0  5.16  5.14  3.18
# 53855   0.51  Ideal     D    VVS2   61.3   57.0  2742.0  5.17  5.14  3.16
# 53884   0.81  Ideal     D     SI1   61.5   57.0  2748.0  6.00  6.03  3.70
# 53935   0.72  Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53939   0.75  Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [2834 rows x 10 columns]

# %%
daimond.columns.str.contains('c.*t')
# Out:
# array([ True,  True, False,  True, False, False, False, False, False,
#        False])

# %%
daimond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    NaN  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    NaN  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    NaN  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    NaN  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    NaN  4.34  4.35  2.75

# %%
daimond=daimond.drop(['x','y','z'],axis=1)

# %%
daimond
# Out:
#        carat        cut color clarity  depth  table   price
# 0       0.23      Ideal     E     SI2   61.5   55.0     NaN
# 1       0.21    Premium     E     SI1   59.8   61.0     NaN
# 2       0.23       Good     E     VS1   56.9   65.0     NaN
# 3       0.29    Premium     I     VS2   62.4   58.0     NaN
# 4       0.31       Good     J     SI2   63.3   58.0     NaN
# ...      ...        ...   ...     ...    ...    ...     ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0
# 53938   0.86    Premium     H     SI2   61.0   58.0  2757.0
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0
#
# [53940 rows x 7 columns]
